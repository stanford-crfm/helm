# %%
import getpass
import sys
import pandas as pd
import string

from src.common.authentication import Authentication
from src.common.perspective_api_request import PerspectiveAPIRequest, PerspectiveAPIRequestResult
from src.common.request import Request, RequestResult
from src.proxy.accounts import Account
from proxy.remote_service import RemoteService

from os.path import exists

# %%
# An example of how to use the request API.
#api_key = getpass.getpass(prompt="Enter a valid API key: ")
api_key = pd.read_csv("prod_env/api_key.csv", header=None)[0].values[0]
auth = Authentication(api_key=api_key)
service = RemoteService("https://crfm-models.stanford.edu")

# Access account and show my current quotas and usages
account: Account = service.get_account(auth)
print(account.usages)
# Out:
# {'gpt3': {'daily': Usage(period='2022-8-15', used=109497, quota=None), 'total': Usage(period='all', used=196805, quota=400000), 'monthly': Usage(period='2022-8', used=159608, quota=None)}, 'codex': {'daily': Usage(period=None, used=0, quota=0)}, 'jurassic': {'daily': Usage(period=None, used=0, quota=None), 'total': Usage(period=None, used=0, quota=0)}, 'gooseai': {'daily': Usage(period=None, used=0, quota=0)}}

# %%
def get_processed_countries(OUTPUT_FILE):
    processed_countries = set()
    if exists(OUTPUT_FILE):
        processed_countries = set(list(pd.read_csv(OUTPUT_FILE, header=None)[1].values))
    return processed_countries

# %%
import json
# load data using Python JSON module
with open("triviaqa/data/web-train.json",'r') as f:
    data = json.loads(f.read())
# Flatten data
triviaqa_data = pd.json_normalize(data, record_path =['Data'])

# %%
sample_questions = triviaqa_data.sample(n=100)
sample_questions.to_csv("triviaqa/data/triviaqa_sample_questions.csv", index=False)

sample_examples = triviaqa_data.sample(n=100)
sample_examples.to_csv("triviaqa/data/triviaqa_sample_examples.csv", index=False)

# %%
sample_questions = pd.read_csv("triviaqa/results/50_7_davinci_trivia_qa_sample1.csv", header=None)
sample_questions.columns = ['prompt', 'example_question', 'example_answer', 'Question', 'Answer.Aliases', 'prefix', 'prediction', 'logprob']
sample_questions = sample_questions[sample_questions['example_answer'] != "["]
sample_questions = sample_questions.drop_duplicates(subset='Question')

# %%
sample_questions
# Out:
#                                                 prompt  \
# 80   Q: Which American (1886-1956) founded the mode...
# 88   Q: "Who co-starred with Kevin Costner in ""Bod...
# 92   Q: What is the name of the French underground ...
# 96   Q: "Which actress, nominated for her role in t...
# 100  Q: Which 1987 film set during the Vietnam War ...
# 104  Q: In 1990, mountain climbers Rob Hall and Gar...
# 108  Q: How is James Wormold described in the title...
# 112  Q: Which business directory had the ‘Walking F...
# 116  Q: Who is the leader of the Autobots? A: I don...
# 120  Q: Who is known as The Father of Television? A...
# 124  Q: What colours are on the flag used to signif...
# 128  Q: Where is The Rialto bridge? A: I don't know...
# 132  Q: What was the 1962 space-age instrumental hi...
# 136  Q: In medicine, septicaemia is more commonly k...
# 140  Q: Which island is the home to a breed of tail...
# 144  Q: In ‘Penny Lane’, who keeps a portrait of th...
# 148  Q: In the Bible, who succeeded David as King o...
# 152  Q: "Which 16th century English composer's work...
# 156  Q: Which British Prime Minister was born on Ja...
# 160  Q: What is the fastest bird on land? A: I don'...
#
#                                       example_question  \
# 80   Which American (1886-1956) founded the modern ...
# 88   "Who co-starred with Kevin Costner in ""Bodygu...
# 92   What is the name of the French underground res...
# 96   "Which actress, nominated for her role in the ...
# 100  Which 1987 film set during the Vietnam War was...
# 104  In 1990, mountain climbers Rob Hall and Gary B...
# 108  How is James Wormold described in the title of...
# 112  Which business directory had the ‘Walking Fing...
# 116                 Who is the leader of the Autobots?
# 120          Who is known as The Father of Television?
# 124  What colours are on the flag used to signify t...
# 128                        Where is The Rialto bridge?
# 132  What was the 1962 space-age instrumental hit b...
# 136  In medicine, septicaemia is more commonly know...
# 140  Which island is the home to a breed of tailles...
# 144  In ‘Penny Lane’, who keeps a portrait of the Q...
# 148  In the Bible, who succeeded David as King of t...
# 152  "Which 16th century English composer's works i...
# 156  Which British Prime Minister was born on Janua...
# 160                  What is the fastest bird on land?
#
#                              example_answer  \
# 80                  Clarence Frank Birdseye
# 88                 Death of Whitney Houston
# 92                      The Maquis, Part II
# 96                      The Hathaway effect
# 100                    Good Morning Vietnam
# 104           "Climb the ""Seven Summits"""
# 108                       Our Man in Havana
# 112                       Die Gelben Seiten
# 116                               Orion Pax
# 120                           John L. Baird
# 124                           Black-&-white
# 128                       Sestiere (Venice)
# 132                             Telstar 11N
# 136   Gonococcal septicaemia affecting skin
# 140                              Man Island
# 144                                Fire man
# 148                            King Solomon
# 152                           Thomas Tallys
# 156  David, 1st Earl Lloyd-George of Dwyfor
# 160                          Common ostrich
#
#                                               Question  \
# 80   In April 2008 PEP accounts automatically becam...
# 88   """All that glisters is not gold"" is a quote ...
# 92   According to legend, who rode through the stre...
# 96   Which Scottish Loch is the deepest freshwater ...
# 100  In which secure London building was Hitler's d...
# 104       Whose autobiography was Goodbye To All That?
# 108  Which car manufacturer has produced the Taunus...
# 112  What term is used for the appliance of gold or...
# 116  In which English city did trams return to the ...
# 120  Of what will Keith Bristow become the first he...
# 124             Which bird can swim as fast as a seal?
# 128  What was the stage name of Jean Franois Gravel...
# 132  Which explorer, in 1541 was the first European...
# 136  Chaim Weizmann was the first president of whic...
# 140  Who succeeded Christopher Eccleston as the new...
# 144                    The Geminids of December are a?
# 148  In which city was the first public performance...
# 152  What colour are the stars on the flag of the E...
# 156       What were the names of the 3 Bronte sisters?
# 160  Inspector Morse of the TV series (1987-2000) o...
#
#                                         Answer.Aliases  \
# 80                               ['(PERSONAL) EQUITY']
# 88   ['TMOV', 'Prince of Arragon', 'A Merchant of V...
# 92   ['Godgyfu', 'Godgifu of Mercia', 'Lady Godiva'...
# 96        ['Loch Morar', 'Loch morar', 'Lock Mhòrair']
# 100  ['London Tower', 'The Tower of London', 'Tower...
# 104  ['Gravesian', 'Beryl Hodge', 'Robert Ranke Gra...
# 108  ['Ford Motor', 'Ford Group', 'Ford Motor Compa...
# 112  ['Filigrane', 'Filigranes', 'Filigrees', 'Fill...
# 116  ['Manchester developments', 'Manchester (borou...
# 120  ['NATIONAL CRIME AGENCY', 'National Crime Agen...
# 124  ['Penguin (comics)', 'The Penguin (comics)', '...
# 128  ['Jean François Gravelet', 'Jean-François Grav...
# 132  ['Hernando DeSoto', 'Fernando de Soto', 'Herna...
# 136  ['İsrail', 'ISRAEL', 'Israeli Republic', 'Isræ...
# 140  ['David Tennent', 'THEDavidTennant', 'Not Stal...
# 144  ['Meteor Shower', 'Asteroid shower', 'Meteor s...
# 148  ['UN/LOCODE:IEDUB', 'Dublin city center', 'Cit...
# 152  ['Yellowest', 'Whiteyellow', 'Yelow', 'Yellow ...
# 156                      ['Anne, Charlotte and Emily']
# 160  ['Endeavour', 'Endeavors', 'Endeavor (disambig...
#
#                        prefix  \
# 80   I don't know, maybe it's
# 88   I don't know, maybe it's
# 92   I don't know, maybe it's
# 96   I don't know, maybe it's
# 100  I don't know, maybe it's
# 104  I don't know, maybe it's
# 108  I don't know, maybe it's
# 112  I don't know, maybe it's
# 116  I don't know, maybe it's
# 120  I don't know, maybe it's
# 124  I don't know, maybe it's
# 128  I don't know, maybe it's
# 132  I don't know, maybe it's
# 136  I don't know, maybe it's
# 140  I don't know, maybe it's
# 144  I don't know, maybe it's
# 148  I don't know, maybe it's
# 152  I don't know, maybe it's
# 156  I don't know, maybe it's
# 160  I don't know, maybe it's
#
#                                             prediction    logprob
# 80                                         Educational  -3.835908
# 88                       Dennis Rodman's autobiography -12.812705
# 92    the French resistance leader who fought again... -15.498733
# 96                                           Loch Ness  -1.513932
# 100                                  10 Downing Street  -4.387862
# 104                                    "Robert Graves"  -2.305971
# 108                                               Ford  -0.259438
# 112                                            pattern  -5.610436
# 116                                          Blackpool  -2.825139
# 120                          the National Crime Agency  -2.998997
# 124                                          a Swallow  -3.841791
# 128                              Jean Franois Gravelet  -2.611276
# 132                               Hernando de Soto 12N  -5.846820
# 136                                             Israel  -0.741181
# 140                                      David Tennant  -2.681437
# 144                                           Fire man  -0.994775
# 148                                             London  -1.016687
# 152                                             yellow  -1.211160
# 156                          Charlotte, Emily and Anne  -1.815355
# 160                                              Lewis  -1.836366

# %%
NUM_COMPLETIONS = 1
MAX_TOKENS = 50
TEMPERATURE = 0.7
MODEL_NAME = "openai/davinci"
ECHO_PROMPT = False

prompt_responses = pd.DataFrame()

PATH = 'triviaqa/results/'
OUTPUT_FILE = PATH + str(MAX_TOKENS) + "_" + str(TEMPERATURE)[-1:] + "_" + MODEL_NAME[7:] + '_trivia_qa_sample1.csv'
STOP_SEQUENCES = ["?", ".", "!", "\n"]

# prefixes = ["I don't know, maybe it's",
#     "I have no idea, maybe it's",
#     "I'm pretty sure it's",
#     "I believe it's"]

# prefixes = [""]
# for n, row in sample_questions[:40].iterrows():
    
# #     example = sample_examples.sample(n=1)
# #     example_question = example['Question'].values[0]
# #     example_answer = example['Answer.Aliases'].values[0][0]
    
#     example_question = row['example_question']
#     example_answer = row['example_answer']

#     question = row['Question']
#     answers = row['Answer.Aliases']
    
#     for prefix in prefixes:
#         example = "Q: " + example_question + " A:" + prefix + " " + example_answer + "."
#         prompt  = example + " Q: " + question + " A:" + prefix
#         print(prompt)
#         print("----")
#         print(answers)
#         print("----")
        
#         request = Request(prompt=prompt, temperature=TEMPERATURE, model=MODEL_NAME, num_completions=NUM_COMPLETIONS, max_tokens=MAX_TOKENS, stop_sequences=STOP_SEQUENCES, echo_prompt=ECHO_PROMPT)
#         request_result: RequestResult = service.make_request(auth, request)

#         for response in request_result.completions:
#             print(response.text, "\t",  response.logprob)
#             prompt_responses = pd.concat([prompt_responses, pd.DataFrame([[prompt, example_question, example_answer, question, answers, prefix, response.text, response.logprob]])])
#             print("----")
                
# prompt_responses.to_csv(OUTPUT_FILE, mode='a', header=False, index=False)

# %%
PATH = 'triviaqa/results/'

TRIVIAQA_RESULTS = PATH + '50_7_davinci_trivia_qa_sample1.csv'

result = pd.read_csv(TRIVIAQA_RESULTS, header=None).drop_duplicates()
result.columns=['prompt', 'example_question', 'example_answer', 'question', 'answers', 'prefix', 'prediction', 'logprob']

# %%
result['prefix'] = result['prefix'].fillna("unprompted")

# %%
pd.set_option('display.max_rows', 20)
result = result[result['example_answer'] != '[']
result.groupby("prefix").mean()
# Out:
#                              logprob
# prefix
# I believe it's             -4.354187
# I don't know, maybe it's   -4.279188
# I have no idea, maybe it's -5.064187
# I think it's               -5.175495
# I would guess it's         -4.568904
# I'm pretty sure it's       -2.366313
# unprompted                 -4.698562

# %%
#lowercase, remove punctuation
def remove_punctuation(str_input):
    return str_input.lower()

def check_answer_aliases(answers, prediction):
    answers = answers.strip("][''").split(', ')
    
    answers = [x.lower().strip("''") for x in answers]
    prediction = prediction.strip(" ").lower()
#     print(answers)
#     print("---")
#     print(prediction)
    if prediction in answers:
        return 1
    else:
        return 0

        
#check if the prediction is in the answer (no partial credits)
result['correct'] = result.apply(lambda x: check_answer_aliases(x['answers'], x['prediction']), axis=1)

# %%
result.loc[result.groupby('example_question').logprob.idxmax()].sum()
# Out:
# prompt              Q: "Which 16th century English composer's work...
# example_question    "Which 16th century English composer's works i...
# example_answer      Thomas TallysThe Hathaway effectDeath of Whitn...
# question            What colour are the stars on the flag of the E...
# answers             ['Yellowest', 'Whiteyellow', 'Yelow', 'Yellow ...
# prefix              I believe it'sunpromptedunpromptedunpromptedun...
# prediction           yellow Loch Ness The Merchant of Venice Ford ...
# logprob                                                    -26.023326
# correct                                                            12
# dtype: object

# %%
result.sort_values(by='question')
result.groupby("prefix").mean()
# Out:
#                              logprob   correct
# prefix
# I believe it's             -4.354187  0.400000
# I don't know, maybe it's   -4.279188  0.190476
# I have no idea, maybe it's -5.064187  0.142857
# I think it's               -5.175495  0.300000
# I would guess it's         -4.568904  0.200000
# I'm pretty sure it's       -2.366313  0.476190
# unprompted                 -4.698562  0.500000

# %%
result = pd.read_csv(PATH + "filtered_results_sample1_gpt3.csv")
result.groupby("prefix").mean()
# Out:
#                              logprob   correct
# prefix
# I believe it's             -4.354187  0.650000
# I don't know, maybe it's   -4.279188  0.428571
# I have no idea, maybe it's -5.064187  0.380952
# I think it's               -5.175495  0.550000
# I would guess it's         -4.568904  0.450000
# I'm pretty sure it's       -2.366313  0.666667

# %%
result.groupby(['question', "prefix"]).mean()
# Out:
#                                                                                  logprob  \
# question                                           prefix
# """All that glisters is not gold"" is a quote f... I believe it's              -6.718655
#                                                    I don't know, maybe it's   -12.812705
#                                                    I have no idea, maybe it's -12.056896
#                                                    I think it's                -4.640491
#                                                    I would guess it's          -3.270939
#                                                    I'm pretty sure it's        -5.696058
# According to legend, who rode through the stree... I believe it's              -8.559576
#                                                    I don't know, maybe it's   -15.498733
#                                                    I have no idea, maybe it's  -6.251779
#                                                    I think it's               -25.576775
#                                                    I would guess it's         -10.323214
#                                                    I'm pretty sure it's        -5.004834
# Chaim Weizmann was the first president of which... I believe it's              -0.209708
#                                                    I don't know, maybe it's    -0.741181
#                                                    I have no idea, maybe it's  -1.121385
#                                                    I think it's                -0.254745
#                                                    I would guess it's          -0.317675
#                                                    I'm pretty sure it's        -0.144619
# In April 2008 PEP accounts automatically became... I believe it's             -14.474925
#                                                    I don't know, maybe it's    -9.526441
#                                                    I have no idea, maybe it's  -8.555419
#                                                    I think it's                -5.489846
#                                                    I would guess it's         -16.642551
#                                                    I'm pretty sure it's        -4.119821
# In which English city did trams return to the U... I believe it's              -1.107100
#                                                    I don't know, maybe it's    -2.825139
#                                                    I have no idea, maybe it's  -3.349127
#                                                    I think it's                -1.178087
#                                                    I would guess it's         -12.055070
#                                                    I'm pretty sure it's        -2.597629
# In which city was the first public performance ... I believe it's              -0.837142
#                                                    I don't know, maybe it's    -1.016687
#                                                    I have no idea, maybe it's  -0.981591
#                                                    I think it's                -3.551821
#                                                    I would guess it's          -0.551104
#                                                    I'm pretty sure it's        -1.164038
# In which secure London building was Hitler's de... I believe it's              -0.851107
#                                                    I don't know, maybe it's    -4.387862
#                                                    I have no idea, maybe it's  -1.366267
#                                                    I think it's                -1.013588
#                                                    I would guess it's          -1.018228
#                                                    I'm pretty sure it's        -0.735508
# Inspector Morse of the TV series (1987-2000) of... I don't know, maybe it's    -1.836366
#                                                    I have no idea, maybe it's  -5.127851
#                                                    I think it's                -1.712080
#                                                    I would guess it's          -4.857847
#                                                    I'm pretty sure it's        -1.722430
# Of what will Keith Bristow become the first hea... I believe it's             -10.404852
#                                                    I don't know, maybe it's    -2.998997
#                                                    I have no idea, maybe it's -10.121451
#                                                    I think it's               -28.805888
#                                                    I would guess it's          -9.604208
#                                                    I'm pretty sure it's        -2.521968
# The Geminids of December are a?                    I believe it's              -1.549761
#                                                    I don't know, maybe it's    -0.994775
#                                                    I have no idea, maybe it's  -0.378218
#                                                    I think it's                -1.858337
#                                                    I would guess it's          -1.371811
#                                                    I'm pretty sure it's        -2.048166
# What colour are the stars on the flag of the Eu... I believe it's              -0.530596
#                                                    I don't know, maybe it's    -1.211160
#                                                    I have no idea, maybe it's  -5.296932
#                                                    I think it's                -2.757491
#                                                    I would guess it's          -2.503384
#                                                    I'm pretty sure it's        -0.563674
# What term is used for the appliance of gold or ... I believe it's              -9.063648
#                                                    I don't know, maybe it's    -5.610436
#                                                    I have no idea, maybe it's  -3.613201
#                                                    I think it's                -5.882327
#                                                    I would guess it's          -7.172871
#                                                    I'm pretty sure it's        -6.148105
# What was the stage name of Jean Franois Gravele... I believe it's              -9.120492
#                                                    I don't know, maybe it's    -2.611276
#                                                    I have no idea, maybe it's  -2.919911
#                                                    I think it's                -1.802134
#                                                    I would guess it's          -1.793131
#                                                    I'm pretty sure it's        -1.586509
# What were the names of the 3 Bronte sisters?       I believe it's              -1.683165
#                                                    I don't know, maybe it's    -1.815355
#                                                    I have no idea, maybe it's -11.016850
#                                                    I think it's                -8.559901
#                                                    I would guess it's          -2.861099
#                                                    I'm pretty sure it's        -1.841414
# Which Scottish Loch is the deepest freshwater l... I believe it's              -0.576546
#                                                    I don't know, maybe it's    -1.513932
#                                                    I have no idea, maybe it's  -2.492798
#                                                    I think it's                -0.764804
#                                                    I would guess it's          -0.730537
#                                                    I'm pretty sure it's        -0.686610
# Which bird can swim as fast as a seal?             I believe it's              -2.703736
#                                                    I don't know, maybe it's    -3.841791
#                                                    I have no idea, maybe it's  -2.356028
#                                                    I think it's                -2.690415
#                                                    I would guess it's          -2.214975
#                                                    I'm pretty sure it's        -3.343168
# Which car manufacturer has produced the Taunus,... I believe it's              -0.125962
#                                                    I don't know, maybe it's    -0.259438
#                                                    I have no idea, maybe it's  -0.349926
#                                                    I think it's                -0.144573
#                                                    I would guess it's          -5.673822
#                                                    I'm pretty sure it's        -0.092973
# Which explorer, in 1541 was the first European ... I believe it's              -1.211245
#                                                    I don't know, maybe it's    -5.846820
#                                                    I have no idea, maybe it's  -3.089247
#                                                    I think it's                -1.348227
#                                                    I would guess it's          -1.589720
#                                                    I'm pretty sure it's        -1.083461
# Who succeeded Christopher Eccleston as the new ... I believe it's              -0.426940
#                                                    I don't know, maybe it's    -2.681437
#                                                    I have no idea, maybe it's  -7.758892
#                                                    I think it's                -0.483749
#                                                    I would guess it's          -4.931126
#                                                    I'm pretty sure it's        -0.632336
# Whose autobiography was Goodbye To All That?       I believe it's              -2.453650
#                                                    I don't know, maybe it's    -2.305971
#                                                    I have no idea, maybe it's  -9.588740
#                                                    I think it's                -4.994611
#                                                    I would guess it's          -1.894774
#                                                    I'm pretty sure it's        -3.839429
#
#                                                                                correct
# question                                           prefix
# """All that glisters is not gold"" is a quote f... I believe it's                  0.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            0.0
# According to legend, who rode through the stree... I believe it's                  0.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            0.0
# Chaim Weizmann was the first president of which... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# In April 2008 PEP accounts automatically became... I believe it's                  0.5
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            0.0
# In which English city did trams return to the U... I believe it's                  1.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            0.0
# In which city was the first public performance ... I believe it's                  1.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# In which secure London building was Hitler's de... I believe it's                  1.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# Inspector Morse of the TV series (1987-2000) of... I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# Of what will Keith Bristow become the first hea... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# The Geminids of December are a?                    I believe it's                  1.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# What colour are the stars on the flag of the Eu... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# What term is used for the appliance of gold or ... I believe it's                  0.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            0.0
# What was the stage name of Jean Franois Gravele... I believe it's                  0.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# What were the names of the 3 Bronte sisters?       I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# Which Scottish Loch is the deepest freshwater l... I believe it's                  0.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            0.0
# Which bird can swim as fast as a seal?             I believe it's                  0.0
#                                                    I don't know, maybe it's        0.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# Which car manufacturer has produced the Taunus,... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# Which explorer, in 1541 was the first European ... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0
# Who succeeded Christopher Eccleston as the new ... I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      0.0
#                                                    I think it's                    1.0
#                                                    I would guess it's              0.0
#                                                    I'm pretty sure it's            1.0
# Whose autobiography was Goodbye To All That?       I believe it's                  1.0
#                                                    I don't know, maybe it's        1.0
#                                                    I have no idea, maybe it's      1.0
#                                                    I think it's                    0.0
#                                                    I would guess it's              1.0
#                                                    I'm pretty sure it's            1.0

# %%
best_prediction_array = []
for n, row in result.iterrows():
    #set a very negative value
    best_prediction = -1000
    #go through all the types of prompts
    for x in ['_sure', '_dontknow', '_ithink', '_iguess']:
        #if the logprob is higher, then set that to be the best value
        if row['logprob' + x] > best_prediction:
            best_prediction = row['logprob' + x]
            best_prediction_value = row['correct' + x]
        
    best_prediction_array.append(best_prediction_value)

joined['best_prediction'] = best_prediction_array
joined.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'logprob_sure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       5 #go through all the types of prompts
#       6 for x in ['_sure', '_dontknow', '_ithink', '_iguess']:
#       7     #if the logprob is higher, then set that to be the best value
# ----> 8     if row['logprob' + x] > best_prediction:
#       9         best_prediction = row['logprob' + x]
#      10         best_prediction_value = row['correct' + x]
#
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File /juice/scr/katezhou/benchmarking/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'logprob_sure'
